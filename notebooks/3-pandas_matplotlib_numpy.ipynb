# %% [markdown]
# # Python scientifique
#
# ## NumPy
#
# NumPy est une bibliothèque Python qui fournit des fonctionnalités de calcul numérique.
# Elle est utilisée comme base pour d'autres bibliothèques Python comme Pandas, Matplotlib, etc.
#
# Documentation officielle :
# https://numpy.org/doc/stable/
#
# NumPy est particulièrement utile pour les opérations sur les tableaux et les matrices.

# %%
import numpy as np
# Out:
# array([ 10.2, 110.1, 210. , 309.9, 409.8, 509.7, 609.6, 709.5, 809.4,
#        909.3])

# %%
np.zeros((10, 4))  # matrice de dimension 10x4 remplie de zéros

# %%
np.ones((10, 4))

# %%
np.ones((10, 4)) * 15  # vectorisation => multiplication de chaque élément par 15 // PAS de boucle sur les éléments
# Out:
# array([[15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.],
#        [15., 15., 15., 15.]])

# %%
np.arange(10.2, 1000.9, 99.9)
